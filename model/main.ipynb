# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.utils import resample
from scipy.signal import resample as scipy_resample
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix
random_seed = 1024
import numpy as np # linear algebra
np.random.seed(random_seed) 
import joblib

# %%
# Input data files are available in the "./data" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('./input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# ./input/ptbdb_abnormal.csv
# ./input/mitbih_test.csv
# ./input/ptbdb_normal.csv
# ./input/mitbih_train.csv

# %%
# Data Exploration (MIT-BIH)
mitbih_train_loc = "./input/mitbih_train.csv"
mitbih_test_loc = "./input/mitbih_test.csv"
mitbih_train_df = pd.read_csv(mitbih_train_loc, header=None)
mitbih_test_df = pd.read_csv(mitbih_test_loc, header=None)

dataset = pd.concat([mitbih_train_df, mitbih_test_df], axis=0, sort=True).reset_index(drop=True)

# %%
labels = dataset.iloc[:, -1].astype('category').map({
    0: 'N - Normal Beat', 
    1: 'S - Supraventricular premature or ectopic beat',
    2: 'V - Premature ventricular contraction', 
    3: 'F - Fusion of ventricular and normal beat', 
    4: 'Q - Unclassified beat'}) 

# since the last column is the category
obs = np.array(dataset.iloc[:, :187])

# %%
# get the indexes of all labels
n_indexes = labels.index[labels == 'N - Normal Beat']
q_indexes = labels.index[labels == 'Q - Unclassified beat']
v_indexes = labels.index[labels == 'V - Premature ventricular contraction']
s_indexes = labels.index[labels == 'S - Supraventricular premature or ectopic beat']
f_indexes = labels.index[labels == 'F - Fusion of ventricular and normal beat']

# sample one observation per class by indexing the train_labels
n_index = n_indexes[0]
q_index = q_indexes[0]
v_index = v_indexes[0]
s_index = s_indexes[0]
f_index = f_indexes[0]

def generate_subplot(figure, obs, gridspec, row, col, title):
    axis = figure.add_subplot(gridspec[row, col])
    axis.plot(np.linspace(0, 1, obs.shape[0]), obs)
    axis.set_title(title)

# Plot samples
fig = plt.figure(figsize=(12, 8))
fig.subplots_adjust(hspace=0.5, wspace=0.001)
gs = fig.add_gridspec(5, 1)

generate_subplot(fig, obs[n_index], gs, 0, 0, 'N - Normal Beat')
generate_subplot(fig, obs[q_index], gs, 1, 0, 'Q - Unclassified beat')
generate_subplot(fig, obs[v_index], gs, 2, 0, 'V - Premature ventricular contraction')
generate_subplot(fig, obs[s_index], gs, 3, 0, 'S - Supraventricular premature or ectopic beat')
generate_subplot(fig, obs[f_index], gs, 4, 0, 'F - Fusion of ventricular and normal beat')

plt.show()

# %%
observation_counts = labels.value_counts()
labels_descending = np.array(observation_counts.keys())

fig1, ax1 = plt.subplots()
ax1.pie(observation_counts, labels=labels_descending, autopct='%1.1f%%', startangle=0, shadow=True)
ax1.axis('equal')
fig1.set_size_inches(12,8)
ax1.set_title("Percentage Distribution of Heartbeat Classes", fontsize=20)
plt.show()

# %%
print(observation_counts)
# Out:
# 187
# N - Normal Beat                                   90589
# Q - Unclassified beat                              8039
# V - Premature ventricular contraction              7236
# S - Supraventricular premature or ectopic beat     2779
# F - Fusion of ventricular and normal beat           803
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

random_seed = 42  # Or any seed value you want

# Resample indexes of each class
n_indexes_resampled = resample(n_indexes, replace=True, n_samples=10000, random_state=random_seed)
q_indexes_resampled = resample(q_indexes, replace=True, n_samples=10000, random_state=random_seed)
v_indexes_resampled = resample(v_indexes, replace=True, n_samples=10000, random_state=random_seed)
s_indexes_resampled = resample(s_indexes, replace=True, n_samples=10000, random_state=random_seed)
f_indexes_resampled = resample(f_indexes, replace=True, n_samples=10000, random_state=random_seed)

# Initialize the labels_resampled to empty pandas Series
labels_resampled = pd.Series(dtype=labels.dtype)

# Initialize obs_resampled as an empty array with the correct number of features
obs_resampled = np.empty((0, obs.shape[1]), dtype=obs.dtype)

# List of resampled indexes
label_indexes_list = [n_indexes_resampled, 
                      q_indexes_resampled, 
                      v_indexes_resampled, 
                      s_indexes_resampled, 
                      f_indexes_resampled]

for label_indexes in label_indexes_list:
    # Append labels for all resampled classes
    labels_resampled = pd.concat([labels_resampled, labels[label_indexes]], ignore_index=True)
    
    # Append observations for all resampled classes
    obs_resampled = np.concatenate((obs_resampled, obs[label_indexes]), axis=0)

# %%
observation_counts = labels_resampled.value_counts()
labels_descending = np.array(observation_counts.keys())

fig1, ax1 = plt.subplots()
ax1.pie(observation_counts, labels=labels_descending, autopct='%1.1f%%', startangle=0, shadow=True)
ax1.axis('equal')
fig1.set_size_inches(12,8)
ax1.set_title("Percentage Distribution of Heartbeat Classes (Resampled)", fontsize=20)
plt.show()

# %%
print(observation_counts)
# Out:
# N - Normal Beat                                   10000
# S - Supraventricular premature or ectopic beat    10000
# V - Premature ventricular contraction             10000
# F - Fusion of ventricular and normal beat         10000
# Q - Unclassified beat                             10000
# Name: count, dtype: int64

# %%
from scipy.signal import resample

# first version of adding random noise (Gaussian Noise)
mean = 0
std = 0.05
def add_gaussian_noise(signal):
    noise = np.random.normal(mean, std, signal.shape)
    return signal + noise

def stretch(x):
    l = int(x.shape[0] * (1 + (random.random() - 0.5) / 3))
    y = scipy_resample(x, l)
    if l < x.shape[0]:
        y_ = np.zeros(x.shape)
        y_[:l] = y
    else:
        y_ = y[:x.shape[0]]
    return y_

def amplify(x):
    alpha = (random.random() - 0.5)
    factor = -alpha * x + (1 + alpha)
    return x * factor

def add_amplify_and_stretch_noise(x):
    if random.random() < 0.33:
        return stretch(x)
    elif random.random() < 0.66:
        return amplify(x)
    else:
        return amplify(stretch(x))

obs_resampled_with_noise_1 = np.array([add_gaussian_noise(obs) for obs in obs_resampled])
obs_resampled_with_noise_2 = np.array([add_amplify_and_stretch_noise(obs) for obs in obs_resampled])

# %%
def generate_plots_for_a_specific_data_augmentation(obs_resampled, obs_resampled_with_noise_1, obs_resampled_with_noise_2):
    # Sample one observation per class by indexing the train_labels
    n_index = 0
    q_index = 10000
    v_index = 20000
    s_index = 30000
    f_index = 40000
    
    fig = plt.figure(figsize=(15, 15))
    fig.subplots_adjust(hspace=0.5, wspace=0.001)
    gs = fig.add_gridspec(5, 3)

    generate_subplot(fig, obs_resampled[n_index], gs, 0, 0, 'N - Normal Beat \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[n_index], gs, 0, 1, 'N - Normal Beat \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[n_index], gs, 0, 2, 'N - Normal Beat \n(with random noise v2)')
    generate_subplot(fig, obs_resampled[q_index], gs, 1, 0, 'Q - Unclassified beat \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[q_index], gs, 1, 1, 'Q - Unclassified beat \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[q_index], gs, 1, 2, 'Q - Unclassified beat \n(with random noise v2)')
    generate_subplot(fig, obs_resampled[v_index], gs, 2, 0, 'V - Premature ventricular contraction \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[v_index], gs, 2, 1, 'V - Premature ventricular contraction \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[v_index], gs, 2, 2, 'V - Premature ventricular contraction \n(with random noise v2)')
    generate_subplot(fig, obs_resampled[s_index], gs, 3, 0, 'S - Supraventricular premature or ectopic beat \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[s_index], gs, 3, 1, 'S - Supraventricular premature or ectopic beat \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[s_index], gs, 3, 2, 'S - Supraventricular premature or ectopic beat \n(with random noise v2)')
    generate_subplot(fig, obs_resampled[f_index], gs, 4, 0, 'F - Fusion of ventricular and normal beat \n(Original)')
    generate_subplot(fig, obs_resampled_with_noise_1[f_index], gs, 4, 1, 'F - Fusion of ventricular and normal beat \n(with random noise v1)')
    generate_subplot(fig, obs_resampled_with_noise_2[f_index], gs, 4, 2, 'F - Fusion of ventricular and normal beat \n(with random noise v2)')

    plt.show()

generate_plots_for_a_specific_data_augmentation(obs_resampled, obs_resampled_with_noise_1, obs_resampled_with_noise_2)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# Prepare the final dataset for training
obs_resampled_final = np.concatenate((obs_resampled, obs_resampled_with_noise_1, obs_resampled_with_noise_2), axis=0)
labels_resampled_final = pd.concat([labels_resampled, labels_resampled, labels_resampled], ignore_index=True)

# Convert labels to numeric format (if not already)
label_mapping = {label: idx for idx, label in enumerate(labels_resampled_final.unique())}
labels_numeric = labels_resampled_final.map(label_mapping).values

# Split the data
X_train, X_test, y_train, y_test = train_test_split(obs_resampled_final, labels_numeric, test_size=0.2, random_state=42)

# Ensure X_train and X_test are NumPy arrays and not categorical
X_train = np.array(X_train)
X_test = np.array(X_test)

# If y_train or y_test are still in a categorical format, convert them to int
y_train = np.array(y_train, dtype=int)
y_test = np.array(y_test, dtype=int)

# Define the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(len(label_mapping), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=300, validation_split=0.2, batch_size=100)

# Make predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=label_mapping.keys())

# Print the results
print(f'Test Accuracy (Overall): {accuracy * 100:.2f}%')
print(report)

# Generate individual class accuracies
unique_labels = np.unique(y_test)
class_accuracies = {}

for label in unique_labels:
    label_idx = (y_test == label)
    class_accuracy = accuracy_score(y_test[label_idx], y_pred[label_idx])
    class_accuracies[label] = class_accuracy

for label, acc in class_accuracies.items():
    print(f'Test Accuracy of {list(label_mapping.keys())[label]}: {acc * 100:.2f}% ({sum(y_test == label)}/{len(y_test)})')
# Out:
# 2024-09-22 15:45:47.855408: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1
300
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.2458 - val_accuracy: 0.9630
# Epoch 193/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.2370 - val_accuracy: 0.9665
# Epoch 194/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.2490 - val_accuracy: 0.9661
# Epoch 195/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.2380 - val_accuracy: 0.9662
# Epoch 196/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.2778 - val_accuracy: 0.9600
# Epoch 197/300
# 960/960 [==============================] - 9s 9ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.2392 - val_accuracy: 0.9667
# Epoch 198/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.2345 - val_accuracy: 0.9663
# Epoch 199/300
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.2406 - val_accuracy: 0.9683
# Epoch 200/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.2350 - val_accuracy: 0.9671
# Epoch 201/300
# 960/960 [==============================] - 5s 6ms/step - loss: 0.0148 - accuracy: 0.9953 - val_loss: 0.2584 - val_accuracy: 0.9629
# Epoch 202/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.2403 - val_accuracy: 0.9661
# Epoch 203/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.2517 - val_accuracy: 0.9653
# Epoch 204/300
# 960/960 [==============================] - 9s 10ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.2441 - val_accuracy: 0.9653
# Epoch 205/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.2493 - val_accuracy: 0.9664
# Epoch 206/300
# 960/960 [==============================] - 9s 9ms/step - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.2559 - val_accuracy: 0.9632
# Epoch 207/300
# 960/960 [==============================] - 19s 20ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.2374 - val_accuracy: 0.9668
# Epoch 208/300
# 960/960 [==============================] - 10s 10ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.2566 - val_accuracy: 0.9647
# Epoch 209/300
# 960/960 [==============================] - 8s 9ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.2527 - val_accuracy: 0.9668
# Epoch 210/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.2353 - val_accuracy: 0.9671
# Epoch 211/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.2560 - val_accuracy: 0.9658
# Epoch 212/300
# 960/960 [==============================] - 14s 15ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.2487 - val_accuracy: 0.9654
# Epoch 213/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.2608 - val_accuracy: 0.9629
# Epoch 214/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.2434 - val_accuracy: 0.9663
# Epoch 215/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.2812 - val_accuracy: 0.9635
# Epoch 216/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.2677 - val_accuracy: 0.9653
# Epoch 217/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.2434 - val_accuracy: 0.9672
# Epoch 218/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.2566 - val_accuracy: 0.9652
# Epoch 219/300
# 960/960 [==============================] - 5s 6ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.2421 - val_accuracy: 0.9663
# Epoch 220/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.2580 - val_accuracy: 0.9648
# Epoch 221/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.2421 - val_accuracy: 0.9678
# Epoch 222/300
# 960/960 [==============================] - 5s 6ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.2566 - val_accuracy: 0.9675
# Epoch 223/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.2640 - val_accuracy: 0.9650
# Epoch 224/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.2533 - val_accuracy: 0.9665
# Epoch 225/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 0.2638 - val_accuracy: 0.9645
# Epoch 226/300
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.2519 - val_accuracy: 0.9657
# Epoch 227/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.2410 - val_accuracy: 0.9664
# Epoch 228/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.2513 - val_accuracy: 0.9647
# Epoch 229/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.2565 - val_accuracy: 0.9669
# Epoch 230/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.2662 - val_accuracy: 0.9650
# Epoch 231/300
# 960/960 [==============================] - 9s 10ms/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 0.2586 - val_accuracy: 0.9649
# Epoch 232/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.2872 - val_accuracy: 0.9623
# Epoch 233/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.2544 - val_accuracy: 0.9657
# Epoch 234/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.2520 - val_accuracy: 0.9657
# Epoch 235/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.2500 - val_accuracy: 0.9668
# Epoch 236/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.2661 - val_accuracy: 0.9649
# Epoch 237/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.2561 - val_accuracy: 0.9671
# Epoch 238/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.2596 - val_accuracy: 0.9654
# Epoch 239/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.2453 - val_accuracy: 0.9679
# Epoch 240/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.2604 - val_accuracy: 0.9642
# Epoch 241/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.2486 - val_accuracy: 0.9664
# Epoch 242/300
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.2968 - val_accuracy: 0.9612
# Epoch 243/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0121 - accuracy: 0.9964 - val_loss: 0.2637 - val_accuracy: 0.9661
# Epoch 244/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.2753 - val_accuracy: 0.9653
# Epoch 245/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.2568 - val_accuracy: 0.9667
# Epoch 246/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.2619 - val_accuracy: 0.9648
# Epoch 247/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0116 - accuracy: 0.9965 - val_loss: 0.2875 - val_accuracy: 0.9629
# Epoch 248/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.2623 - val_accuracy: 0.9680
# Epoch 249/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.2620 - val_accuracy: 0.9664
# Epoch 250/300
# 960/960 [==============================] - 8s 9ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.2556 - val_accuracy: 0.9667
# Epoch 251/300
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.2596 - val_accuracy: 0.9675
# Epoch 252/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.2856 - val_accuracy: 0.9619
# Epoch 253/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.2776 - val_accuracy: 0.9651
# Epoch 254/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.2582 - val_accuracy: 0.9672
# Epoch 255/300
# 960/960 [==============================] - 9s 9ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.2462 - val_accuracy: 0.9685
# Epoch 256/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.2764 - val_accuracy: 0.9627
# Epoch 257/300
# 960/960 [==============================] - 9s 10ms/step - loss: 0.0106 - accuracy: 0.9968 - val_loss: 0.2889 - val_accuracy: 0.9626
# Epoch 258/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.2547 - val_accuracy: 0.9675
# Epoch 259/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.2706 - val_accuracy: 0.9661
# Epoch 260/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.2569 - val_accuracy: 0.9683
# Epoch 261/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0142 - accuracy: 0.9956 - val_loss: 0.2701 - val_accuracy: 0.9665
# Epoch 262/300
# 960/960 [==============================] - 10s 10ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.2528 - val_accuracy: 0.9683
# Epoch 263/300
# 960/960 [==============================] - 10s 11ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.2790 - val_accuracy: 0.9666
# Epoch 264/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.2869 - val_accuracy: 0.9623
# Epoch 265/300
# 960/960 [==============================] - 9s 10ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.2726 - val_accuracy: 0.9658
# Epoch 266/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.2601 - val_accuracy: 0.9685
# Epoch 267/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.2741 - val_accuracy: 0.9643
# Epoch 268/300
# 960/960 [==============================] - 8s 9ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.2577 - val_accuracy: 0.9668
# Epoch 269/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.2784 - val_accuracy: 0.9638
# Epoch 270/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.2621 - val_accuracy: 0.9680
# Epoch 271/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.2552 - val_accuracy: 0.9680
# Epoch 272/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.2790 - val_accuracy: 0.9667
# Epoch 273/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.2542 - val_accuracy: 0.9676
# Epoch 274/300
# 960/960 [==============================] - 9s 9ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.2551 - val_accuracy: 0.9648
# Epoch 275/300
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.2726 - val_accuracy: 0.9672
# Epoch 276/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.2799 - val_accuracy: 0.9661
# Epoch 277/300
# 960/960 [==============================] - 10s 10ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.3094 - val_accuracy: 0.9588
# Epoch 278/300
# 960/960 [==============================] - 9s 9ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.2657 - val_accuracy: 0.9665
# Epoch 279/300
# 960/960 [==============================] - 8s 9ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.2619 - val_accuracy: 0.9661
# Epoch 280/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.2763 - val_accuracy: 0.9660
# Epoch 281/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0109 - accuracy: 0.9964 - val_loss: 0.2998 - val_accuracy: 0.9635
# Epoch 282/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.3075 - val_accuracy: 0.9626
# Epoch 283/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.2629 - val_accuracy: 0.9683
# Epoch 284/300
# 960/960 [==============================] - 10s 10ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.2777 - val_accuracy: 0.9652
# Epoch 285/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0090 - accuracy: 0.9969 - val_loss: 0.2547 - val_accuracy: 0.9676
# Epoch 286/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.2788 - val_accuracy: 0.9661
# Epoch 287/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.2662 - val_accuracy: 0.9663
# Epoch 288/300
# 960/960 [==============================] - 7s 8ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.2634 - val_accuracy: 0.9692
# Epoch 289/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.2852 - val_accuracy: 0.9635
# Epoch 290/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.2590 - val_accuracy: 0.9690
# Epoch 291/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.3058 - val_accuracy: 0.9643
# Epoch 292/300
# 960/960 [==============================] - 6s 7ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.2724 - val_accuracy: 0.9674
# Epoch 293/300
# 960/960 [==============================] - 5s 5ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.2701 - val_accuracy: 0.9665
# Epoch 294/300
# 960/960 [==============================] - 5s 6ms/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 0.3483 - val_accuracy: 0.9602
# Epoch 295/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.2638 - val_accuracy: 0.9691
# Epoch 296/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.3059 - val_accuracy: 0.9637
# Epoch 297/300
# 960/960 [==============================] - 6s 6ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.2750 - val_accuracy: 0.9664
# Epoch 298/300
# 960/960 [==============================] - 8s 8ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.2657 - val_accuracy: 0.9670
# Epoch 299/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.2777 - val_accuracy: 0.9664
# Epoch 300/300
# 960/960 [==============================] - 7s 7ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.2610 - val_accuracy: 0.9666
# 938/938 [==============================] - 2s 2ms/step
# Test Accuracy (Overall): 96.75%
#                                                 precision    recall  f1-score   support
#
#                                N - Normal Beat       0.94      0.95      0.94      5982
#                          Q - Unclassified beat       0.99      0.99      0.99      5959
#          V - Premature ventricular contraction       0.98      0.97      0.98      5983
# S - Supraventricular premature or ectopic beat       0.97      0.96      0.96      5986
#      F - Fusion of ventricular and normal beat       0.97      0.97      0.97      6090
#
#                                       accuracy                           0.97     30000
#                                      macro avg       0.97      0.97      0.97     30000
#                                   weighted avg       0.97      0.97      0.97     30000
#
# Test Accuracy of N - Normal Beat: 94.60% (5982/30000)
# Test Accuracy of Q - Unclassified beat: 99.13% (5959/30000)
# Test Accuracy of V - Premature ventricular contraction: 97.14% (5983/30000)
# Test Accuracy of S - Supraventricular premature or ectopic beat: 95.81% (5986/30000)
# Test Accuracy of F - Fusion of ventricular and normal beat: 97.08% (6090/30000)

# %%
from sklearn.metrics import confusion_matrix

# Prepare the mapping for the labels
label_mapping = {label: idx for idx, label in enumerate(labels_resampled.unique())}
labels_numeric = labels_resampled_final.map(label_mapping).values

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=list(label_mapping.values()))

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[5659   27   34  161  101]
#  [  26 5907   13    7    6]
#  [  52   12 5812   25   82]
#  [ 211   12   17 5735   11]
#  [ 100    5   59   14 5912]]

# %%
cm
# Out:
# array([[5659,   27,   34,  161,  101],
#        [  26, 5907,   13,    7,    6],
#        [  52,   12, 5812,   25,   82],
#        [ 211,   12,   17, 5735,   11],
#        [ 100,    5,   59,   14, 5912]])

# %%
joblib.dump(model, 'model.pk1')
# Out:
# ['model.pk1']

# %%
model.save('model.h5')

# %%
print(tf.version.VERSION)
# Out:
# 2.12.0

# %%
model.save('model.keras')

# %%
new_model = tf.keras.models.load_model('model.keras')
